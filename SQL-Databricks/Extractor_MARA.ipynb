# %%
import pandas as pd
import databricks.sql as dbsql
 
# Replace the following placeholders with your actual values
server_hostname = "adb-8914414801116949.9.azuredatabricks.net"
http_path = "/sql/1.0/warehouses/001e7dd02e3b1957"
access_token = "dapi1629a7ae6bdcd3599400c554c4343e2f-3" #token valido hasta 2025-02-02
 
# Establish the connection
connection = dbsql.connect(
    server_hostname=server_hostname,
    http_path=http_path,
    access_token=access_token
)
cursor = connection.cursor()
 
# Example query
query = "SELECT * FROM dercoparts.curated.tbl_saprt_f_mara"
 
cursor.execute(query)
 
# Fetch the results and get the column names
results = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
 
# Close the cursor and connection
cursor.close()
connection.close()
 
# Create a pandas DataFrame
df = pd.DataFrame(results, columns=columns)
 
# Display the DataFrame
#print(df)

# %%
ruta = r"C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentoss\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\SQL-Databricks\Maestros\Sector_MU.xlsx"
mu = pd.read_excel(ruta)

# %%
# Unir los DataFrames
df = df.merge(mu[['Sector_MU', 'Nombre Sector']], on='Sector_MU', how='left')

# %%
columnas_seleccionadas = [
    "Material", "Texto_breve_material", "Nombre Sector", "tpo_material_mu", "Gpo_art", "Unidad_medida_base", "Sector_MU", "tpo_material_mu", "PartNumber", "Gpo_art_externo", 
    "Nro_material_ant", "Marca", "Marca_txt"
]

mara= df[columnas_seleccionadas]
mara
# Out:
#                   Material                    Texto_breve_material  \
# 0       000000000001172384              LUB LUBRITEK AW 46 MIN 19L
# 1       000000000001172267               FILTRO DE AIRE 15100158AA
# 2       000000000001172351  AROM SPRAY AUTO FRESCO FRESA 100ML SIM
# 3       000000000001171963         LLAVERO N°17 MOTORLIFE AP240822
# 4       000000000001172222                   FILTRO CABINA CU 2629
# ...                    ...                                     ...
# 451914  000000000000537779    AMORTIGUADOR DE SUSPENSION DELANTERA
# 451915  000000000000110905                               FAROL-TYC
# 451916  000000000000111334                 TAPA BENCINA H110670 UN
# 451917  000000000000112831              NEB-KM-MORNING-DER (04-08)
# 451918  000000000000555444   TERMOSTATO DEL REFRIGERANTE DEL MOTOR
#
#        Nombre Sector tpo_material_mu    Gpo_art Unidad_medida_base Sector_MU  \
# 0                LUB            ZREP  080202007                 UN        31
# ...

# %%
mara.loc[:, "Material"] = mara["Material"].astype(str).str.lstrip("0")
mara.head(20)
# Out:
#    Material                    Texto_breve_material Nombre Sector  \
# 0   1172384              LUB LUBRITEK AW 46 MIN 19L           LUB
# 1   1172267               FILTRO DE AIRE 15100158AA          RALT
# 2   1172351  AROM SPRAY AUTO FRESCO FRESA 100ML SIM           ACC
# 3   1171963         LLAVERO N°17 MOTORLIFE AP240822           ACC
# 4   1172222                   FILTRO CABINA CU 2629          RALT
# 5   1172240            FILTRO DE AIRE 0313AAM00521N          RALT
# 6   1006476      BAT VARTA MF105D31R 90AH 640CCA BK           BAT
# 7   1172339  CERA PASTA VISTA SIMONIZ 255GR SIMONIZ           ACC
# 8   1172349         AROM AEROSOL AQUA 110ML SIMONIZ           ACC
# 9   1172365     KIT FILTROS CHEVROLET N400 20 AL 24          RALT
# 10   100525                 FIL ACEITE MANN W920/25          RALT
# 11   107595               DISCO FRENO GTX DF-305 UN          RALT
# 12  1172315   LIMPIAVIDRIOS ANTIEMPANANTE 350ML SIM           ACC
# ...

# %%
mu
# Out:
#    Sector_MU Nombre Sector
# 0         48           ACC
# 1         28           AXS
# 2         03       Renault
# 3         02         Mazda
# 4         01        Suzuki
# ..       ...           ...
# 60        08             0
# 61        42             0
# 62        16       Hesston
# 63        19         Stara
# 64        40             0
#
# [65 rows x 2 columns]

# %%
ruta_archivo_guardado = r"C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentoss\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\SQL-Databricks\Maestros\MARA.xlsx"
mara.to_excel(ruta_archivo_guardado, index=False)
