# %% [markdown]
# # AUTOARIMA

# %%
import pandas as pd
import numpy as np

ruta_archivo = r"C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentos\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\Ciclo\SI_SO Ciclo Sep-2024AE.csv"
df = pd.read_csv(ruta_archivo, delimiter=',', decimal=',', encoding='utf-8').rename(columns={'Canal': 'Canal 3', 'Cantidad': 'Venta', 'idSKU': 'Ultimo Eslabón'})
df['ID'] = df['Ultimo Eslabón'].astype(str) + df['Canal 3'].astype(str)
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%Y-%m-%d')
df = df.sort_values(by=['Ultimo Eslabón', 'Fecha']).reset_index(drop=True)
pivot_table = df.pivot_table(index=['Ultimo Eslabón', 'Canal 3'], columns='Fecha', values='Venta', fill_value=0).reset_index()
pivot_table = pivot_table[pivot_table.iloc[:, 2:].sum(axis=1) != 0]
ultima_fecha = pivot_table.columns[-1]
primer_fecha = ultima_fecha - pd.DateOffset(months=23)
ventas_ultimos_24_meses = pivot_table.loc[:, primer_fecha:ultima_fecha]
intervalos = ventas_ultimos_24_meses.apply(lambda x: (x != 0).astype(int).diff().fillna(1).abs().sum(), axis=1)
ventas_activas = (ventas_ultimos_24_meses != 0).sum(axis=1)
pivot_table['ADI'] = intervalos / ventas_activas
ventas_no_cero = ventas_ultimos_24_meses.replace(0, np.nan)
pivot_table['CV²'] = (ventas_no_cero.std(axis=1) / ventas_no_cero.mean(axis=1)) ** 2
def clasificar_demanda(row):
    if row['ADI'] < 1.32 and row['CV²'] < 0.49: return 'Smooth'
    elif row['ADI'] >= 1.32 and row['CV²'] < 0.49: return 'Intermittent'
    elif row['ADI'] < 1.32 and row['CV²'] >= 0.49: return 'Erratic'
    else: return 'Lumpy'
pivot_table['Demand Type'] = pivot_table.apply(clasificar_demanda, axis=1)
melted_data = pivot_table.melt(id_vars=['Ultimo Eslabón', 'Canal 3', 'ADI', 'CV²', 'Demand Type'], var_name='Fecha', value_name='Venta')
melted_data['Fecha'] = pd.to_datetime(melted_data['Fecha'], format='%Y-%m-%d')
data = melted_data
data.shape

# %% [markdown]
# ## Intermittent

# %%
data = melted_data[melted_data['Demand Type'] == 'Intermittent']
data = data[['Ultimo Eslabón', 'Canal 3', 'Fecha', 'Venta']]
data

# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
import os

# Asumiendo que las fechas están en formato 'YYYY-MM-DD'
data['ID'] = data.apply(lambda row: f"{row['Ultimo Eslabón']}_{row['Canal 3']}", axis=1)
data['Fecha'] = pd.to_datetime(data['Fecha'], format='%Y-%m-%d')  # Mantén el formato original

predictions = []

# Simulamos estar en diciembre de 2023 pero queremos predecir a partir de enero de 2024
# Usaremos todos los datos hasta julio de 2024
for id_value in data['ID'].unique():
    data_id = data[data['ID'] == id_value]
    data_id.set_index('Fecha', inplace=True, drop=True)
    data_id.index.freq = 'MS'  # Esto supone que las fechas son mensuales y consecutivas
    y = data_id['Venta']
    
    if y.isnull().any() or np.isinf(y).any():
        print(f'Serie temporal con valores nulos o infinitos para ID: {id_value}')
        continue
    
    try:
        # Ajustar AutoARIMA para encontrar el mejor modelo ARIMA
        model = auto_arima(y, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True)
        future_predictions = model.predict(n_periods=12)
        
        # Crear las fechas de predicción a partir de enero de 2024
        future_dates = pd.date_range(start='2024-01-01', periods=12, freq='MS').strftime('%Y-%m-%d')
        
        for date, pred in zip(future_dates, future_predictions):
            predictions.append({
                'ID': id_value,
                'Fecha': date,
                'Prediccion_Venta': pred
            })
    except Exception as e:
        print(f'Error al ajustar el modelo para ID: {id_value} - {e}')
        continue

predictions_df = pd.DataFrame(predictions)
output_dir = r'C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentos\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\Ciclo'
output_file = os.path.join(output_dir, 'AutoArima_Intermittent.csv')
predictions_df.to_csv(output_file, index=False, sep=';', decimal=',')

print(f'Predicciones guardadas en {output_file}')

# %% [markdown]
# ## Erratic

# %%
import pandas as pd
import numpy as np

ruta_archivo = r"C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentos\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\Ciclo\SI_SO Ciclo Sep-2024AE.csv"
df = pd.read_csv(ruta_archivo, delimiter=',', decimal=',', encoding='utf-8').rename(columns={'Canal': 'Canal 3', 'Cantidad': 'Venta', 'idSKU': 'Ultimo Eslabón'})
df['ID'] = df['Ultimo Eslabón'].astype(str) + df['Canal 3'].astype(str)
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%Y-%m-%d')
df = df.sort_values(by=['Ultimo Eslabón', 'Fecha']).reset_index(drop=True)
pivot_table = df.pivot_table(index=['Ultimo Eslabón', 'Canal 3'], columns='Fecha', values='Venta', fill_value=0).reset_index()
pivot_table = pivot_table[pivot_table.iloc[:, 2:].sum(axis=1) != 0]
ultima_fecha = pivot_table.columns[-1]
primer_fecha = ultima_fecha - pd.DateOffset(months=23)
ventas_ultimos_24_meses = pivot_table.loc[:, primer_fecha:ultima_fecha]
intervalos = ventas_ultimos_24_meses.apply(lambda x: (x != 0).astype(int).diff().fillna(1).abs().sum(), axis=1)
ventas_activas = (ventas_ultimos_24_meses != 0).sum(axis=1)
pivot_table['ADI'] = intervalos / ventas_activas
ventas_no_cero = ventas_ultimos_24_meses.replace(0, np.nan)
pivot_table['CV²'] = (ventas_no_cero.std(axis=1) / ventas_no_cero.mean(axis=1)) ** 2
def clasificar_demanda(row):
    if row['ADI'] < 1.32 and row['CV²'] < 0.49: return 'Smooth'
    elif row['ADI'] >= 1.32 and row['CV²'] < 0.49: return 'Intermittent'
    elif row['ADI'] < 1.32 and row['CV²'] >= 0.49: return 'Erratic'
    else: return 'Lumpy'
pivot_table['Demand Type'] = pivot_table.apply(clasificar_demanda, axis=1)
melted_data = pivot_table.melt(id_vars=['Ultimo Eslabón', 'Canal 3', 'ADI', 'CV²', 'Demand Type'], var_name='Fecha', value_name='Venta')
melted_data['Fecha'] = pd.to_datetime(melted_data['Fecha'], format='%Y-%m-%d')
data = melted_data
data.shape

# %%
data = melted_data[melted_data['Demand Type'] == 'Erratic']
data = data[['Ultimo Eslabón', 'Canal 3', 'Fecha', 'Venta']]
data

# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
import os

# Asumiendo que las fechas están en formato 'YYYY-MM-DD'
data['ID'] = data.apply(lambda row: f"{row['Ultimo Eslabón']}_{row['Canal 3']}", axis=1)
data['Fecha'] = pd.to_datetime(data['Fecha'], format='%Y-%m-%d')  # Mantén el formato original

predictions = []

# Simulamos estar en diciembre de 2023 pero queremos predecir a partir de enero de 2024
# Usaremos todos los datos hasta julio de 2024
for id_value in data['ID'].unique():
    data_id = data[data['ID'] == id_value]
    data_id.set_index('Fecha', inplace=True, drop=True)
    data_id.index.freq = 'MS'  # Esto supone que las fechas son mensuales y consecutivas
    y = data_id['Venta']
    
    if y.isnull().any() or np.isinf(y).any():
        print(f'Serie temporal con valores nulos o infinitos para ID: {id_value}')
        continue
    
    try:
        # Ajustar AutoARIMA para encontrar el mejor modelo ARIMA
        model = auto_arima(y, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True)
        future_predictions = model.predict(n_periods=12)
        
        # Crear las fechas de predicción a partir de enero de 2024
        future_dates = pd.date_range(start='2024-01-01', periods=12, freq='MS').strftime('%Y-%m-%d')
        
        for date, pred in zip(future_dates, future_predictions):
            predictions.append({
                'ID': id_value,
                'Fecha': date,
                'Prediccion_Venta': pred
            })
    except Exception as e:
        print(f'Error al ajustar el modelo para ID: {id_value} - {e}')
        continue

predictions_df = pd.DataFrame(predictions)
output_dir = r'C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentos\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\Ciclo'
output_file = os.path.join(output_dir, 'AutoArima_Erratic.csv')
predictions_df.to_csv(output_file, index=False, sep=';', decimal=',')

print(f'Predicciones guardadas en {output_file}')

# %% [markdown]
# ## Smooth

# %%
import pandas as pd
import numpy as np

ruta_archivo = r"C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentos\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\Ciclo\SI_SO Ciclo Sep-2024AE.csv"
df = pd.read_csv(ruta_archivo, delimiter=',', decimal=',', encoding='utf-8').rename(columns={'Canal': 'Canal 3', 'Cantidad': 'Venta', 'idSKU': 'Ultimo Eslabón'})
df['ID'] = df['Ultimo Eslabón'].astype(str) + df['Canal 3'].astype(str)
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%Y-%m-%d')
df = df.sort_values(by=['Ultimo Eslabón', 'Fecha']).reset_index(drop=True)
pivot_table = df.pivot_table(index=['Ultimo Eslabón', 'Canal 3'], columns='Fecha', values='Venta', fill_value=0).reset_index()
pivot_table = pivot_table[pivot_table.iloc[:, 2:].sum(axis=1) != 0]
ultima_fecha = pivot_table.columns[-1]
primer_fecha = ultima_fecha - pd.DateOffset(months=23)
ventas_ultimos_24_meses = pivot_table.loc[:, primer_fecha:ultima_fecha]
intervalos = ventas_ultimos_24_meses.apply(lambda x: (x != 0).astype(int).diff().fillna(1).abs().sum(), axis=1)
ventas_activas = (ventas_ultimos_24_meses != 0).sum(axis=1)
pivot_table['ADI'] = intervalos / ventas_activas
ventas_no_cero = ventas_ultimos_24_meses.replace(0, np.nan)
pivot_table['CV²'] = (ventas_no_cero.std(axis=1) / ventas_no_cero.mean(axis=1)) ** 2
def clasificar_demanda(row):
    if row['ADI'] < 1.32 and row['CV²'] < 0.49: return 'Smooth'
    elif row['ADI'] >= 1.32 and row['CV²'] < 0.49: return 'Intermittent'
    elif row['ADI'] < 1.32 and row['CV²'] >= 0.49: return 'Erratic'
    else: return 'Lumpy'
pivot_table['Demand Type'] = pivot_table.apply(clasificar_demanda, axis=1)
melted_data = pivot_table.melt(id_vars=['Ultimo Eslabón', 'Canal 3', 'ADI', 'CV²', 'Demand Type'], var_name='Fecha', value_name='Venta')
melted_data['Fecha'] = pd.to_datetime(melted_data['Fecha'], format='%Y-%m-%d')
data = melted_data
data.shape
# Out:
# (4701211, 7)

# %%
data = melted_data[melted_data['Demand Type'] == 'Smooth']
data = data[['Ultimo Eslabón', 'Canal 3', 'Fecha', 'Venta']]
data
# Out:
#          Ultimo Eslabón    Canal 3       ADI       CV² Demand Type      Fecha  \
# 9                100481  CL RETAIL  0.041667  0.075945      Smooth 2018-01-01
# 12               100485  CL RETAIL  0.086957  0.258048      Smooth 2018-01-01
# 13               100486  CL RETAIL  0.111111  0.091449      Smooth 2018-01-01
# 14               100487  CL RETAIL  0.041667  0.266401      Smooth 2018-01-01
# 17               100491  CL RETAIL  0.111111  0.155451      Smooth 2018-01-01
# ...                 ...        ...       ...       ...         ...        ...
# 4701197         1171461  CL RETAIL  1.000000  0.000000      Smooth 2024-07-01
# 4701200         1171471  CL RETAIL  1.000000  0.000000      Smooth 2024-07-01
# 4701202         1171474  CL RETAIL  1.000000  0.000000      Smooth 2024-07-01
# 4701204         1171481  CL RETAIL  1.000000  0.000000      Smooth 2024-07-01
# 4701209         1171584  CL RETAIL  0.041667  0.154618      Smooth 2024-07-01
#
#          Venta
# 9         63.0
# 12         0.0
# 13         0.0
# 14         0.0
# 17         0.0
# ...        ...
# 4701197    3.0
# 4701200    1.0
# 4701202    1.0
# 4701204    2.0
# 4701209   10.0
#
# [845221 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
import os

# Asumiendo que las fechas están en formato 'YYYY-MM-DD'
data['ID'] = data.apply(lambda row: f"{row['Ultimo Eslabón']}_{row['Canal 3']}", axis=1)
data['Fecha'] = pd.to_datetime(data['Fecha'], format='%Y-%m-%d')  # Mantén el formato original

predictions = []

# Simulamos estar en diciembre de 2023 pero queremos predecir a partir de enero de 2024
# Usaremos todos los datos hasta julio de 2024
for id_value in data['ID'].unique():
    data_id = data[data['ID'] == id_value]
    data_id.set_index('Fecha', inplace=True, drop=True)
    data_id.index.freq = 'MS'  # Esto supone que las fechas son mensuales y consecutivas
    y = data_id['Venta']
    
    if y.isnull().any() or np.isinf(y).any():
        print(f'Serie temporal con valores nulos o infinitos para ID: {id_value}')
        continue
    
    try:
        # Ajustar AutoARIMA para encontrar el mejor modelo ARIMA
        model = auto_arima(y, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True)
        future_predictions = model.predict(n_periods=12)
        
        # Crear las fechas de predicción a partir de enero de 2024
        future_dates = pd.date_range(start='2024-01-01', periods=12, freq='MS').strftime('%Y-%m-%d')
        
        for date, pred in zip(future_dates, future_predictions):
            predictions.append({
                'ID': id_value,
                'Fecha': date,
                'Prediccion_Venta': pred
            })
    except Exception as e:
        print(f'Error al ajustar el modelo para ID: {id_value} - {e}')
        continue

predictions_df = pd.DataFrame(predictions)
output_dir = r'C:\Users\etorres.DERCOPARTS\DERCO CHILE REPUESTOS SpA\Planificación y abastecimiento - Documentos\Planificación y Compras AFM\S&OP Demanda\Codigos Demanda\Scripts\Ciclo'
output_file = os.path.join(output_dir, 'AutoArima_Smooth.csv')
predictions_df.to_csv(output_file, index=False, sep=';', decimal=',')

print(f'Predicciones guardadas en {output_file}')
# Out:
# C:\Users\etorres.DERCOPARTS\AppData\Local\Temp\ipykernel_2896\1693569103.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ID'] = data.apply(lambda row: f"{row['Ultimo Eslabón']}_{row['Canal 3']}", axis=1)
# C:\Users\etorres.DERCOPARTS\AppData\Local\Temp\ipykernel_2896\1693569103.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Fecha'] = pd.to_datetime(data['Fecha'], format='%Y-%m-%d')  # Mantén el formato original
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=50.66 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=620.160, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=621.008, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=619.756, Time=7.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=618.414, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=25.05 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 83.081 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=43.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=299.719, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=286.780, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=284.241, Time=3.94 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=297.961, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=285.511, Time=8.54 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=285.856, Time=9.48 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=34.82 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=283.184, Time=2.87 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=284.755, Time=5.95 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=284.935, Time=4.86 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=285.420, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=24.23 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 138.312 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=169.968, Time=18.02 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=208.553, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=183.702, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=178.165, Time=5.75 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=206.696, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=177.217, Time=17.63 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=168.494, Time=10.78 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=177.043, Time=7.52 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=170.914, Time=5.59 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=170.285, Time=21.63 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=170.064, Time=9.44 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=53.13 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=167.833, Time=8.33 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=176.398, Time=5.88 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=170.432, Time=4.22 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=169.503, Time=17.28 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=169.114, Time=14.76 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=182.182, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=176.078, Time=12.97 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=169.173, Time=6.12 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=inf, Time=53.67 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 272.835 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=575.830, Time=37.71 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=587.282, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=582.887, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=582.960, Time=6.93 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=585.434, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=586.368, Time=18.44 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=582.900, Time=20.99 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=577.806, Time=38.33 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=577.809, Time=42.81 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=584.659, Time=7.66 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=584.518, Time=24.51 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=580.707, Time=23.02 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=67.74 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=573.969, Time=27.54 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=584.610, Time=10.48 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=581.126, Time=14.18 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=575.950, Time=24.51 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=575.952, Time=29.84 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=582.857, Time=5.07 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=582.592, Time=13.65 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=578.804, Time=13.57 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=576.825, Time=41.69 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 468.725 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=153.314, Time=21.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=173.164, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=155.289, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=148.538, Time=5.60 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=171.264, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=150.532, Time=10.34 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=150.534, Time=10.15 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=152.525, Time=20.77 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=147.557, Time=3.54 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=149.466, Time=5.76 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=149.480, Time=5.38 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=153.571, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=151.462, Time=12.78 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 96.047 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=29.01 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=580.734, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=561.905, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=19.30 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=578.736, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=555.249, Time=8.98 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=552.522, Time=14.79 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=551.616, Time=14.56 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=551.710, Time=25.36 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=52.79 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=35.99 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=58.28 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=549.636, Time=11.05 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=550.535, Time=7.80 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=549.738, Time=14.66 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=540.702, Time=22.03 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=538.733, Time=16.53 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=536.759, Time=8.76 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=534.785, Time=6.46 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=532.789, Time=3.38 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=534.784, Time=7.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=559.909, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=536.766, Time=21.47 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 378.395 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-107.648, Time=55.18 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-115.475, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-113.489, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-113.489, Time=6.49 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-116.469, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-111.580, Time=47.30 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 109.191 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=383.836, Time=32.40 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=487.521, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=394.831, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=440.572, Time=2.86 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=381.853, Time=12.27 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=428.922, Time=5.91 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=383.120, Time=6.83 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=383.851, Time=16.30 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=412.150, Time=10.08 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=381.902, Time=18.15 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=385.431, Time=33.96 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=378.819, Time=21.13 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=380.972, Time=6.40 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=377.578, Time=9.33 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=380.309, Time=4.98 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=376.677, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=392.822, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=377.987, Time=12.60 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=378.921, Time=25.06 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 218.487 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=657.734, Time=34.14 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=689.901, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=669.743, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=677.589, Time=8.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=688.078, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=663.943, Time=21.54 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=671.662, Time=14.36 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=659.260, Time=59.58 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=659.322, Time=60.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=671.348, Time=11.66 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=52.59 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=668.209, Time=22.69 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=67.19 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=655.917, Time=32.77 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=662.059, Time=11.58 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=669.857, Time=10.77 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=657.424, Time=45.23 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=657.503, Time=56.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=669.602, Time=5.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=661.666, Time=28.05 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=666.399, Time=16.24 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=658.358, Time=61.81 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 619.756 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=444.005, Time=25.15 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=445.420, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=446.324, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=446.203, Time=6.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=443.458, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=448.040, Time=11.04 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 42.443 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=358.168, Time=14.45 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=417.955, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=356.607, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=375.096, Time=2.94 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=358.517, Time=3.90 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=358.509, Time=4.73 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=357.416, Time=14.40 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=356.354, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=406.563, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=358.347, Time=4.79 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=358.347, Time=6.91 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=369.571, Time=4.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=360.347, Time=17.82 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 74.236 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=51.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=412.452, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=401.727, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=397.443, Time=4.24 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=410.481, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=399.112, Time=7.48 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=399.243, Time=5.97 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=41.80 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=395.506, Time=2.78 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=397.210, Time=6.25 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=397.316, Time=5.08 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=399.767, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=397.077, Time=18.99 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 144.022 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=368.625, Time=20.67 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=364.019, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=365.586, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=365.466, Time=4.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=362.442, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=25.17 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 49.980 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=292.286, Time=18.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=320.440, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=314.563, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=292.052, Time=5.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=318.455, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=292.771, Time=8.51 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=291.974, Time=19.48 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=293.613, Time=32.77 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=292.544, Time=15.34 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=294.026, Time=21.68 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=290.000, Time=7.86 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=290.055, Time=4.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=291.629, Time=15.10 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=290.544, Time=8.66 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=290.790, Time=6.19 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=292.026, Time=16.47 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 180.440 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=283.069, Time=24.29 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=379.057, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=307.368, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=340.885, Time=3.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=282.069, Time=17.26 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=333.196, Time=6.86 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=280.413, Time=8.93 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=282.160, Time=17.33 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=299.422, Time=4.14 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=275.279, Time=21.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=274.197, Time=4.67 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=274.192, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=274.286, Time=0.13 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 107.884 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=37.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=435.601, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=371.700, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=407.596, Time=2.68 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=353.580, Time=4.56 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=352.195, Time=6.96 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=350.482, Time=9.88 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=348.798, Time=13.98 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=345.633, Time=29.35 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=343.788, Time=23.48 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=342.237, Time=20.33 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=340.729, Time=12.64 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=338.804, Time=6.81 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=340.741, Time=12.24 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=388.606, Time=7.09 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=334.502, Time=22.55 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=334.167, Time=4.23 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=332.517, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=334.059, Time=0.03 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 214.041 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=50.39 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=268.718, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=245.998, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=23.70 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=266.718, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=238.063, Time=3.35 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=232.959, Time=7.78 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=225.205, Time=9.49 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=222.840, Time=11.43 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=73.19 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=222.209, Time=19.45 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=64.39 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=224.183, Time=25.87 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=48.61 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=69.89 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=220.478, Time=15.70 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=219.595, Time=13.52 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=218.275, Time=9.13 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=216.649, Time=6.15 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=215.393, Time=5.26 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=216.509, Time=9.39 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=244.000, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=218.150, Time=10.32 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 477.233 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=185.925, Time=35.20 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=211.989, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=194.629, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=201.506, Time=2.82 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=184.120, Time=22.90 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=195.976, Time=6.51 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=182.694, Time=8.82 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=184.169, Time=15.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=193.090, Time=4.20 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=182.146, Time=13.56 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=180.569, Time=4.35 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=181.364, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=181.805, Time=7.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=180.208, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=182.123, Time=6.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=182.605, Time=32.89 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 159.599 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=333.858, Time=29.55 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=440.195, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=362.082, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=405.516, Time=3.70 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=331.824, Time=13.67 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=386.603, Time=6.90 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=330.649, Time=8.96 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=331.863, Time=8.61 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=343.312, Time=4.23 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=329.189, Time=15.60 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=345.382, Time=4.56 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=341.126, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=330.269, Time=13.49 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=330.200, Time=18.61 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=350.032, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=341.199, Time=7.47 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=334.660, Time=7.37 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=325.718, Time=50.53 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=334.247, Time=29.80 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=334.191, Time=18.75 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=332.071, Time=19.73 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=332.233, Time=24.95 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=334.439, Time=64.60 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 351.248 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=37.62 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=445.102, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=375.763, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=403.042, Time=2.90 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=366.174, Time=3.97 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=357.691, Time=8.15 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=359.666, Time=10.76 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=352.370, Time=18.69 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=350.565, Time=19.59 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=348.680, Time=9.28 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=350.545, Time=12.32 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=400.415, Time=7.17 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=346.631, Time=27.75 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=348.063, Time=5.78 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=347.682, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=348.531, Time=31.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=348.512, Time=37.49 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=349.390, Time=0.01 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=349.961, Time=7.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=349.147, Time=7.54 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=48.40 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 295.685 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=496.918, Time=9.22 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=642.626, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=522.198, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=594.043, Time=4.29 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=494.810, Time=12.16 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=556.841, Time=21.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=492.922, Time=6.35 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=494.755, Time=11.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=498.162, Time=5.48 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=490.509, Time=16.37 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=504.529, Time=7.22 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=498.769, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=491.285, Time=17.53 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=487.147, Time=16.44 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=485.729, Time=14.01 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=486.985, Time=15.43 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=486.578, Time=46.51 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0] intercept
# Total fit time: 203.273 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=35.13 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=396.836, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=379.114, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=354.879, Time=7.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=394.849, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=356.826, Time=9.84 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=356.823, Time=13.51 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=41.42 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=353.768, Time=3.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=355.749, Time=4.76 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=355.747, Time=5.20 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=377.130, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=28.09 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 148.384 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=269.142, Time=11.82 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=337.440, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=265.487, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=298.414, Time=2.60 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=265.348, Time=4.43 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=267.235, Time=6.01 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=30.60 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=265.190, Time=5.87 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=266.320, Time=15.87 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=285.183, Time=5.50 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=256.714, Time=7.38 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=261.284, Time=4.47 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=254.771, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=278.699, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=256.693, Time=6.28 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=258.622, Time=13.99 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 115.047 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=322.462, Time=22.41 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=362.754, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=327.493, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=339.741, Time=2.16 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=320.462, Time=15.49 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=335.321, Time=5.65 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=322.444, Time=7.51 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=322.462, Time=16.37 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=331.717, Time=6.46 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=320.835, Time=15.45 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=324.240, Time=35.07 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=319.807, Time=16.82 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=320.135, Time=7.34 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=319.655, Time=6.15 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=319.422, Time=4.54 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=329.099, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=317.679, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=319.658, Time=5.84 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=320.160, Time=21.71 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 189.045 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=32.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=246.240, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=230.500, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=215.746, Time=9.76 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=244.279, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=24.32 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=26.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=48.83 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=214.778, Time=3.40 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=215.908, Time=5.64 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=216.046, Time=6.95 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=228.575, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=217.589, Time=18.73 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 176.261 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=38.75 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=313.976, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=288.105, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=297.252, Time=2.87 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=284.481, Time=4.11 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=278.692, Time=4.67 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=280.319, Time=7.83 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=277.263, Time=19.84 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=275.594, Time=14.48 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=273.773, Time=6.21 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=275.556, Time=12.62 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=296.116, Time=5.04 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=270.566, Time=12.89 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=270.596, Time=5.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=270.288, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=271.954, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=271.972, Time=6.26 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=272.544, Time=15.27 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 156.102 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=332.748, Time=15.63 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=366.015, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=341.214, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=328.209, Time=6.49 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=364.270, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=330.076, Time=9.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=330.108, Time=9.31 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=331.253, Time=15.42 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=330.022, Time=3.35 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 59.399 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=265.602, Time=17.01 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=317.652, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=297.437, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=270.324, Time=13.43 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=315.750, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=266.413, Time=16.63 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=265.582, Time=12.62 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=269.648, Time=8.35 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=281.294, Time=6.52 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=263.128, Time=16.49 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=263.291, Time=9.61 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=265.067, Time=24.66 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=265.079, Time=20.17 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=263.491, Time=10.01 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=267.036, Time=40.79 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=261.915, Time=11.67 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=264.595, Time=7.64 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=261.787, Time=7.58 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=279.518, Time=4.25 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=262.167, Time=9.46 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=263.902, Time=17.44 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0]
# Total fit time: 254.564 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=403.865, Time=9.43 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=469.608, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=418.345, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=442.888, Time=3.51 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=400.223, Time=15.27 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=431.264, Time=5.84 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=399.866, Time=6.96 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=400.263, Time=12.33 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=414.069, Time=3.73 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=394.893, Time=15.13 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=393.081, Time=4.30 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=394.576, Time=0.01 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=394.801, Time=6.66 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=392.898, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=394.891, Time=6.92 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=396.888, Time=17.94 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 108.081 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=30.26 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=306.161, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=295.579, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=273.441, Time=6.39 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=304.234, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=27.37 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=30.47 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=275.770, Time=31.43 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=273.004, Time=4.03 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=274.452, Time=6.21 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=274.269, Time=5.46 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=293.722, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=275.425, Time=13.80 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 155.626 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=282.513, Time=18.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=326.717, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=303.980, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=314.555, Time=2.85 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=282.576, Time=12.24 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=282.607, Time=9.87 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=284.505, Time=23.81 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=284.503, Time=27.32 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=281.080, Time=7.33 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=307.983, Time=5.13 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=294.271, Time=4.28 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=280.065, Time=15.31 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=282.741, Time=4.20 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=282.473, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=281.499, Time=19.04 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=281.440, Time=16.18 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=281.649, Time=0.01 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=283.399, Time=5.61 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=282.489, Time=7.01 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=281.444, Time=32.18 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 210.863 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=32.47 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=301.086, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=289.775, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=22.68 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=299.105, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=287.860, Time=6.09 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=281.959, Time=6.57 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=281.603, Time=8.22 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=281.372, Time=11.98 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=64.52 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=52.23 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=279.748, Time=10.13 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=279.828, Time=5.95 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=278.183, Time=25.59 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=276.184, Time=15.85 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=274.499, Time=12.25 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=273.403, Time=9.96 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=271.411, Time=6.87 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=271.486, Time=2.57 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=287.820, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=273.407, Time=12.03 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=271.517, Time=4.60 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=285.923, Time=2.79 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=274.498, Time=19.99 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=34.33 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 367.759 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=361.451, Time=20.17 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=440.394, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=373.206, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=409.912, Time=3.29 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=358.791, Time=14.21 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=394.409, Time=5.16 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=357.986, Time=7.86 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=357.422, Time=15.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=363.182, Time=4.72 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=39.97 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=363.382, Time=8.01 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=358.192, Time=42.91 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=350.883, Time=22.28 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=350.644, Time=10.63 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=351.925, Time=3.26 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=350.041, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=354.639, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=350.090, Time=7.47 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 205.136 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=343.948, Time=31.73 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=393.292, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=348.501, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=363.666, Time=2.36 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=342.453, Time=14.82 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=359.970, Time=4.98 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=348.075, Time=8.25 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=344.148, Time=54.87 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=355.873, Time=8.15 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=342.252, Time=21.43 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=349.508, Time=4.14 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=344.011, Time=30.55 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=348.955, Time=7.66 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=345.734, Time=56.85 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=339.473, Time=22.86 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=337.698, Time=9.67 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=336.284, Time=3.85 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=347.719, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=337.908, Time=6.15 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=336.045, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=337.761, Time=6.94 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 295.416 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=236.412, Time=22.38 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=281.945, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=246.670, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=259.209, Time=3.22 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=235.872, Time=12.74 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=257.165, Time=5.55 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=236.437, Time=8.64 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=237.852, Time=17.86 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=246.779, Time=6.69 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=235.865, Time=18.18 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=243.835, Time=4.46 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=241.521, Time=11.12 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=241.565, Time=8.38 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=52.52 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=234.126, Time=13.64 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=232.130, Time=6.32 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=231.143, Time=4.42 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=235.709, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=232.985, Time=8.91 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=230.458, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=232.233, Time=6.64 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 211.756 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=200.337, Time=23.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=226.192, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=222.888, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=225.398, Time=2.15 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=198.821, Time=10.49 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=214.892, Time=4.94 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=201.803, Time=8.26 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=200.461, Time=16.01 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=216.631, Time=7.34 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=198.683, Time=11.16 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=206.967, Time=3.94 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=200.554, Time=16.57 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=206.279, Time=7.04 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=49.78 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=195.807, Time=15.59 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=198.714, Time=12.38 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=195.691, Time=5.28 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=198.561, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=197.527, Time=8.76 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=197.748, Time=27.12 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 230.430 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=375.606, Time=29.46 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=456.507, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=379.175, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=408.375, Time=2.58 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=373.856, Time=5.36 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=394.597, Time=4.91 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=381.153, Time=5.12 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=375.396, Time=24.54 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=392.181, Time=9.45 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=382.469, Time=9.30 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=377.856, Time=22.35 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=371.697, Time=10.93 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=372.229, Time=7.39 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=371.423, Time=6.88 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=375.275, Time=4.65 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=371.506, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=373.334, Time=12.24 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=405.037, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=372.191, Time=7.45 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=373.547, Time=18.42 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 181.204 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=306.052, Time=37.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=381.054, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=312.894, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=346.216, Time=2.84 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=304.378, Time=13.85 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=332.524, Time=4.66 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=305.464, Time=6.98 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=306.059, Time=19.04 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=328.938, Time=6.35 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=304.052, Time=13.22 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=309.553, Time=5.28 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=306.052, Time=18.23 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=308.961, Time=7.62 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=306.650, Time=40.74 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=301.241, Time=23.16 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=299.792, Time=9.88 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=303.895, Time=4.07 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=298.935, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=316.301, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=300.126, Time=5.51 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 218.776 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=422.416, Time=27.92 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=543.568, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=431.767, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=491.155, Time=2.80 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=420.419, Time=13.77 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=469.284, Time=8.00 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=422.705, Time=6.68 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=422.414, Time=15.41 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=461.457, Time=13.59 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=421.184, Time=17.87 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=422.290, Time=45.48 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=416.949, Time=17.71 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=419.283, Time=9.65 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=417.146, Time=9.15 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=418.941, Time=26.17 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=418.935, Time=20.32 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=420.144, Time=5.18 sec
# ...
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=805.819, Time=13.44 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=794.339, Time=18.60 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=792.339, Time=11.15 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=790.343, Time=10.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=791.090, Time=3.54 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=815.755, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=792.339, Time=19.56 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=790.456, Time=8.27 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=794.029, Time=28.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=22.71 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 408.568 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=51.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=725.120, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=599.791, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=676.019, Time=4.63 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=590.206, Time=6.62 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=591.237, Time=8.28 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=584.443, Time=9.66 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=583.042, Time=7.13 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=584.501, Time=13.02 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=639.600, Time=9.96 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=581.687, Time=15.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=598.834, Time=7.96 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=586.346, Time=0.19 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=583.251, Time=33.21 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=583.305, Time=25.74 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=613.977, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=588.415, Time=12.52 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=583.817, Time=10.93 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=43.68 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 259.876 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=246.021, Time=11.49 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=255.166, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=241.076, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=244.164, Time=2.57 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=242.669, Time=4.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=242.487, Time=5.99 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=241.689, Time=23.75 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=236.686, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=243.360, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=238.686, Time=5.27 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=238.686, Time=13.71 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=237.358, Time=3.14 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=240.686, Time=6.81 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 76.996 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=451.223, Time=16.44 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=477.133, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=451.698, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=458.175, Time=3.66 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=449.259, Time=12.31 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=454.078, Time=6.97 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=452.088, Time=7.78 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=451.101, Time=18.74 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=455.829, Time=10.10 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=455.567, Time=17.74 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=450.476, Time=26.22 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=448.537, Time=22.71 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=447.207, Time=9.70 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=447.217, Time=6.34 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=447.858, Time=13.61 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=447.826, Time=9.40 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=450.495, Time=37.32 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0] intercept
# Total fit time: 219.073 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=44.71 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=719.373, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=601.965, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=665.751, Time=3.51 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=603.541, Time=3.54 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=603.577, Time=7.16 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=604.732, Time=10.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=590.059, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=623.733, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=591.499, Time=9.68 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=591.750, Time=12.48 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=600.136, Time=6.40 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=592.282, Time=34.90 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 132.566 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=57.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=362.223, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=355.835, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=344.879, Time=6.51 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=360.226, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=24.03 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=341.967, Time=9.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=36.53 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=37.96 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=50.18 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=340.643, Time=5.26 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=343.098, Time=3.20 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=341.954, Time=12.08 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=341.579, Time=8.91 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=339.956, Time=7.98 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=353.848, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=341.953, Time=9.81 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=352.386, Time=3.85 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=343.956, Time=11.82 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 284.707 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=315.492, Time=34.65 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=359.505, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=332.243, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=310.208, Time=8.64 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=357.587, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=311.921, Time=12.97 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=311.964, Time=11.68 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=313.588, Time=22.82 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=314.320, Time=2.60 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 93.462 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=53.23 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=323.636, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=300.808, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=285.402, Time=10.40 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=321.639, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=26.32 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=38.37 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=287.652, Time=17.47 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=285.762, Time=2.84 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 148.749 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=154.026, Time=22.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=161.878, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=159.692, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=161.182, Time=3.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=154.400, Time=16.29 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=154.259, Time=12.69 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=59.99 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=62.60 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=152.708, Time=11.29 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=158.240, Time=4.37 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=154.710, Time=4.41 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=149.934, Time=14.14 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=148.993, Time=4.74 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=147.103, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=148.957, Time=0.02 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 215.891 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=52.01 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=464.873, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=444.896, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=429.640, Time=4.50 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=462.895, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=431.604, Time=8.90 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=431.609, Time=9.68 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=433.640, Time=11.90 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=428.943, Time=3.64 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=430.943, Time=3.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=430.943, Time=4.66 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=442.967, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=432.662, Time=23.14 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 121.772 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=59.92 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=378.689, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=367.790, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=26.77 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=376.691, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=366.258, Time=7.59 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=359.388, Time=9.52 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=360.413, Time=12.59 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=39.40 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=40.64 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=57.24 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=357.460, Time=7.28 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=364.262, Time=5.77 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=358.542, Time=7.18 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=350.867, Time=13.36 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=350.371, Time=10.80 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=348.473, Time=4.86 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=348.047, Time=4.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=348.467, Time=6.29 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=365.790, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=350.438, Time=12.90 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 326.353 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=291.163, Time=29.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=322.769, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=317.290, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=290.741, Time=7.81 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=320.784, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=39.10 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=14.55 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=55.65 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=290.660, Time=2.78 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=291.071, Time=7.42 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=289.832, Time=13.87 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=290.621, Time=10.88 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=289.315, Time=11.04 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=290.997, Time=20.41 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=290.857, Time=12.22 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=292.802, Time=28.60 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=289.541, Time=33.19 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0]
# Total fit time: 287.277 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=393.682, Time=31.40 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=491.828, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=414.598, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=452.852, Time=4.93 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=392.252, Time=13.58 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=443.390, Time=10.67 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=390.289, Time=6.59 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=392.258, Time=15.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=404.496, Time=4.17 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=386.329, Time=22.10 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=389.988, Time=4.82 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=388.705, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=388.323, Time=25.32 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=388.322, Time=23.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=393.399, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=391.062, Time=9.20 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=389.281, Time=8.54 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=389.799, Time=32.21 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 211.915 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=62.95 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=376.861, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=342.076, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=359.869, Time=3.50 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=328.804, Time=4.33 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=328.697, Time=7.24 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=330.525, Time=8.17 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=24.46 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=29.98 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=55.47 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=317.281, Time=10.50 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=315.281, Time=7.42 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=316.159, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=317.281, Time=15.58 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=316.985, Time=10.25 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=55.43 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 295.428 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=441.853, Time=14.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=476.463, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=471.566, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=474.022, Time=3.11 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=442.193, Time=9.48 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=456.328, Time=10.53 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=46.57 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=433.662, Time=14.65 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=45.83 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=435.601, Time=22.43 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=435.551, Time=33.04 sec
