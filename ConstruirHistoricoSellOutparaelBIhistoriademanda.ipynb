# %%
import pandas as pd
import os

# Obtener el nombre del usuario actual del sistema
usuario = os.getlogin()

# Definir la ruta completa
ruta = r"C:\Users\Etorres\OneDrive - Inchcape\Desktop PC Migración\Codigos Demanda\Historia_Sell_Out_Mayo.parquet"


# Leer el archivo Parquet
sellout_concat = pd.read_parquet(ruta)

# %%
sellout_concat
# Out:
#                Mes Material   Canal  Venta UMB                Fuente  \
# 0       2021-06-01  1000147      AP       52.0  Sell Out MB51 - SISO
# 1       2021-05-01  1000147      AP       40.0  Sell Out MB51 - SISO
# 2       2021-04-01  1000147      AP       18.0  Sell Out MB51 - SISO
# 3       2021-03-01  1000147      AP       34.0  Sell Out MB51 - SISO
# 4       2021-02-01  1000147      AP       41.0  Sell Out MB51 - SISO
# ...            ...      ...     ...        ...                   ...
# 1359881 2024-04-01   747234  Retail        2.0   Sell Out RTL May-24
# 1359882 2024-04-01   752085  Retail        3.0   Sell Out RTL May-24
# 1359883 2024-04-01   752110  Retail        1.0   Sell Out RTL May-24
# 1359884 2024-04-01   760622  Retail        2.0   Sell Out RTL May-24
# 1359885 2024-04-01   760741  Retail        1.0   Sell Out RTL May-24
#
#         Ultimo Eslabón  Tipo Canal 2 Nombre Sector    Canal 3
# 0              1000147   ACC  Retail           ACC  CL RETAIL
# ...

# %%
csv_path = r"C:\Users\Etorres\OneDrive - Inchcape\Desktop PC Migración\Codigos Demanda\SellOut Excel\sellout.csv"

# %%
sellout_concat.to_csv(csv_path, sep=';', decimal=',', index=False)
print(f"Archivo CSV guardado en: {csv_path}")
# pivot_df.to_excel(excel_path, index=False)
# print(f"Archivo Excel guardado en: {excel_path}")
# Out:
# Archivo CSV guardado en: C:\Users\Etorres\OneDrive - Inchcape\Desktop PC Migración\Codigos Demanda\SellOut Excel\sellout.csv
